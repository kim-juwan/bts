# %%
# %matplotlib inline
import pandas as pd
import cx_Oracle as oci
import matplotlib.pyplot as plt

conn = oci.connect('admin/1234@192.168.99.100:32764/xe',encoding='utf-8')
cursor = conn.cursor()

sql = 'SELECT * FROM TAXI'
cursor.execute(sql)
data = cursor.fetchall()

df = pd.DataFrame(data)

df.columns = ['No','기준년월일','요일','시간대','발신지_시도','발신지_시군구','발신지_읍면동','통화건수']

# %%
import plotnine
from plotnine import *

# %%
from matplotlib import font_manager
from matplotlib import rc

font_path = 'C:/Windows/Fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font_name)

# %%
df[df['발신지_시군구'] == '동구']
# Out:
#               No     기준년월일 요일  시간대 발신지_시도 발신지_시군구 발신지_읍면동  통화건수
# 4           4179  20150203  화   10  부산광역시      동구     수정동     5
# 5           4180  20150203  화   10  부산광역시      동구     초량동     5
# 6           4181  20150203  화   10  부산광역시      동구     좌천동     5
# 89          4264  20150203  화   11  부산광역시      동구     범일동     5
# 90          4265  20150203  화   11  부산광역시      동구     초량동     5
# ...          ...       ... ..  ...    ...     ...     ...   ...
# 1995932  1912063  20190527  월   14  부산광역시      동구     수정동     6
# 1995965  1912096  20190527  월   15  부산광역시      동구     좌천동     5
# 1995966  1912097  20190527  월   15  부산광역시      동구     수정동     5
# 1995995  1912126  20190527  월   16  부산광역시      동구     수정동     5
# 1995996  1912127  20190527  월   16  부산광역시      동구     초량동     5
#
# [72684 rows x 8 columns]

# %%
df_table = df.pivot_table('통화건수',columns='발신지_시군구',index='기준년월일',aggfunc='sum',fill_value=0)
df_table
# Out:
# 발신지_시군구   강서구  금정구   기장군    남구   동구  동래구  부산진구   북구   사상구   사하구   서구  수영구  \
# 기준년월일
# 20150201  290  655   768   782  372  678  1374  726   817  1117  382  567
# 20150202  365  693   888  1001  415  874  1555  892  1015  1166  456  620
# 20150203  375  664   892   947  403  871  1475  862   952  1177  439  647
# 20150204  397  763  1006  1092  389  860  1686  927  1042  1301  429  676
# 20150205  369  660  1012   988  394  873  1643  905  1002  1274  470  644
# ...       ...  ...   ...   ...  ...  ...   ...  ...   ...   ...  ...  ...
# 20190926  175  360   726   454  148  590   736  529   429   448  208  236
# 20190927  170  412   849   586  174  766   990  626   522   579  245  283
# 20190928  171  399   912   537  216  808  1111  525   530   583  282  360
# 20190929  120  268   571   328  129  506   616  402   374   387  159  217
# 20190930  155  306   748   407  144  586   702  565   396   433  206  226
#
# 발신지_시군구   연제구  영도구   중구  해운대구
# 기준년월일
# 20150201  423  514  350  1378
# 20150202  536  554  401  1644
# 20150203  507  584  366  1716
# 20150204  610  587  493  1872
# 20150205  571  525  438  1861
# ...       ...  ...  ...   ...
# 20190926  228  189    5   847
# 20190927  272  193    0  1183
# 20190928  278  184    0  1269
# 20190929  163  165    0   765
# 20190930  207  165    0   844
#
# [1703 rows x 16 columns]

# %%
plt.plot(df_table[:10].index,df_table[:10].values)
# Out:
# [<matplotlib.lines.Line2D at 0x1f726a1e448>,
#  <matplotlib.lines.Line2D at 0x1f728017808>,
#  <matplotlib.lines.Line2D at 0x1f728017a08>,
#  <matplotlib.lines.Line2D at 0x1f728017c08>,
#  <matplotlib.lines.Line2D at 0x1f728017e88>,
#  <matplotlib.lines.Line2D at 0x1f7280240c8>,
#  <matplotlib.lines.Line2D at 0x1f7280242c8>,
#  <matplotlib.lines.Line2D at 0x1f7280244c8>,
#  <matplotlib.lines.Line2D at 0x1f728017e08>,
#  <matplotlib.lines.Line2D at 0x1f728024088>,
#  <matplotlib.lines.Line2D at 0x1f7269e4b48>,
#  <matplotlib.lines.Line2D at 0x1f728024d08>,
#  <matplotlib.lines.Line2D at 0x1f728024f88>,
#  <matplotlib.lines.Line2D at 0x1f728026248>,
#  <matplotlib.lines.Line2D at 0x1f7280264c8>,
#  <matplotlib.lines.Line2D at 0x1f728026748>]

# %%
tel = df.groupby('발신지_시군구').sum()['통화건수']

# %%
tel
# Out:
# 발신지_시군구
# 강서구      423338
# 금정구      749021
# 기장군     1543863
# 남구      1156736
# 동구       377180
# 동래구     1405954
# 부산진구    2012629
# 북구      1216579
# 사상구     1146595
# 사하구     1349549
# 서구       653664
# 수영구      704654
# 연제구      623221
# 영도구      599168
# 중구       210301
# 해운대구    2311793
# Name: 통화건수, dtype: int64

# %%
fig = plt.figure(figsize=(10,10))

plt.bar(df_table.columns,tel)
# Out:
# <BarContainer object of 16 artists>

# %%
df2 = df[(df['시간대'] == 7) | (df['시간대'] == 8) | (df['시간대'] == 9)]
morning = df2.groupby('발신지_시군구').sum()['통화건수']
morning
# Out:
# 발신지_시군구
# 강서구      59262
# 금정구     140648
# 기장군     242475
# 남구      259813
# 동구       57698
# 동래구     304233
# 부산진구    428752
# 북구      262261
# 사상구     219318
# 사하구     280307
# 서구      112800
# 수영구     130870
# 연제구     134322
# 영도구     115799
# 중구       27439
# 해운대구    471925
# Name: 통화건수, dtype: int64

# %%
fig = plt.figure(figsize=(10,10))

plt.bar(df_table.columns,morning)
# Out:
# <BarContainer object of 16 artists>

# %%
df2 = df[(df['시간대'] == 7) | (df['시간대'] == 8) | (df['시간대'] == 9)]
morning_m = df2.groupby('발신지_시군구').mean()['통화건수']
morning_m
# Out:
# 발신지_시군구
# 강서구      5.008621
# 금정구      9.534165
# 기장군     13.165110
# 남구      14.334510
# 동구       5.392840
# 동래구     12.057905
# 부산진구    14.001437
# 북구      13.849863
# 사상구      7.981585
# 사하구     10.551344
# 서구       6.342067
# 수영구      8.240665
# 연제구     16.267652
# 영도구      6.582481
# 중구       5.010774
# 해운대구    15.396724
# Name: 통화건수, dtype: float64

# %%
fig = plt.figure(figsize=(10,10))

plt.bar(df_table.columns,morning_m)
# Out:
# <BarContainer object of 16 artists>

# %%
df3 = df[(df['시간대'] == 10) | (df['시간대'] == 11) | (df['시간대'] == 12)]
df3
# Out:
#               No     기준년월일 요일  시간대 발신지_시도 발신지_시군구 발신지_읍면동  통화건수
# 0           4175  20150203  화   10  부산광역시      남구     용호동    16
# 1           4176  20150203  화   10  부산광역시      남구     감만동     5
# 2           4177  20150203  화   10  부산광역시      남구     대연동    22
# 3           4178  20150203  화   10  부산광역시      남구     용당동     5
# 4           4179  20150203  화   10  부산광역시      동구     수정동     5
# ...          ...       ... ..  ...    ...     ...     ...   ...
# 1995787  1908635  20190522  수   12  부산광역시    해운대구      중동     5
# 1995788  1908636  20190522  수   12  부산광역시    해운대구     반여동     5
# 1995789  1908637  20190522  수   12  부산광역시    해운대구     반송동     5
# 1995790  1908638  20190522  수   12  부산광역시    해운대구      우동    11
# 1995791  1908639  20190522  수   12  부산광역시    해운대구      좌동    15
#
# [289827 rows x 8 columns]

# %%
df2 = df[(df['시간대'] == 18) | (df['시간대'] == 19) | (df['시간대'] == 20)]
night_m = df2.groupby('발신지_시군구').mean()['통화건수']
plt.style.use('ggplot')
night_m[['강서구','금정구','기장군','남구','동구','동래구','부산진구','북구','사상구','사하구','서구','수영구','연제구','영도구','중구','해운대구']].plot(kind='bar',figsize=(20,10),width=0.7,color ='lightcoral')
plt.ylim(0,15)
plt.xticks(rotation=45)
plt.xlabel('지역(구)', size=25)
plt.ylabel('평균 콜택시 통화건수', size=25)
plt.title('지역구에 따른 평균 콜택시 통화건수 : 퇴근 시간대',size=30)
# plt.set_xticklabels(df_year_event.index, rotation = 75)
plt.show()
# night_m

# %%
fig = plt.figure(figsize=(10,10))

plt.bar(df_table.columns,night_m)
# Out:
# <BarContainer object of 16 artists>

# %%
df2 = df[(df['시간대'] == 18) | (df['시간대'] == 19) | (df['시간대'] == 20)]
night_m = df2.groupby('발신지_시군구').sum()['통화건수']
plt.style.use('ggplot')
night_m[['강서구','금정구','기장군','남구','동구','동래구','부산진구','북구','사상구','사하구','서구','수영구','연제구','영도구','중구','해운대구']].plot(kind='bar',figsize=(20,10),width=0.7,color ='mediumslateblue')
plt.ylim(0,350000)
plt.xticks(rotation=45)
plt.xlabel('지역(구)', size=25)
plt.ylabel('총 콜택시 통화건수',size=25)


plt.title('지역구에 따른 콜택시 통화건수 총합 : 퇴근 시간대',size=30)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))

plt.bar(df_table.columns,night_m)
# Out:
# <BarContainer object of 16 artists>

# %%
df_table = df2.pivot_table('통화건수',columns='발신지_시군구',index='요일',aggfunc='sum',fill_value=0)
df_table
# Out:
# 발신지_시군구    강서구    금정구    기장군     남구    동구    동래구   부산진구     북구    사상구    사하구  \
# 요일
# 금        10767  15202  45117  27709  8055  31905  46527  26268  24362  28651
# 목        10139  13254  37672  22342  7371  25987  39432  21745  21148  23297
# 수         9762  13802  38232  22728  7439  25948  39359  22373  21757  24508
# 월         8934  12278  35012  19826  7142  22986  35811  20437  19621  21858
# 일         8242  12281  30830  17058  7002  20381  30185  20299  17808  21039
# 토        11148  14279  42641  24296  7720  28946  42296  26289  22751  28079
# 화         9271  12885  36003  21012  7080  24442  36849  20728  20646  22871
#
# 발신지_시군구     서구    수영구    연제구    영도구    중구   해운대구
# 요일
# 금        13674  15123  14221  12284  4221  60114
# 목        12161  12600  11842  10736  3802  48967
# 수        12731  12964  11970  11125  3967  47742
# 월        11510  11814  10698  10296  3659  43324
# 일        10740  10624   8682   9710  3500  36161
# 토        13069  13916  11700  11814  4036  54870
# 화        11988  12279  11121  10617  3772  45055

# %%
fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(1,1,1)
ax.plot(df_table.loc[:,'기장군'],marker= 'o', markersize = 10, color = 'olive', markerfacecolor='green', linewidth = 2, label = '기장군')
ax.plot(df_table.loc[:,'해운대구'],marker= 'o', markersize = 10, color = 'orange', markerfacecolor='orange', linewidth = 2, label = '해운대구')
ax.plot(df_table.loc[:,'부산진구'],marker= 'o', markersize = 10, color = 'red', markerfacecolor='magenta', linewidth = 2, label = '부산진구')
# ax.plot(df_table.loc[:,'금정구'],marker= 'o', markersize = 10, color = 'blue', markerfacecolor='blue', linewidth = 2, label = '금정구')
# ax.plot(df_table.loc[:,'강서구'],marker= 'o', markersize = 10, color = 'blue', markerfacecolor='blue', linewidth = 2, label = '강서구')
# ax.plot(df_table.loc[:,'남구'],marker= 'o', markersize = 10, color = 'blue', markerfacecolor='blue', linewidth = 2, label = '남구')
# ax.plot(df_table.loc[:,'동구'],marker= 'o', markersize = 10, color = 'blue', markerfacecolor='blue', linewidth = 2, label = '동구')
ax.plot(df_table.loc[:,'동래구'],marker= 'o', markersize = 10, color = 'blue', markerfacecolor='blue', linewidth = 2, label = '동래구')
# ax.plot(df_table.loc[:,'북구'],marker= 'o', markersize = 10, color = 'blue', markerfacecolor='blue', linewidth = 2, label = '북구')
# ax.plot(df_table.loc[:,'사상구'],marker= 'o', markersize = 10, color = 'blue', markerfacecolor='blue', linewidth = 2, label = '사상구')
# ax.plot(df_table.loc[:,'서구'],marker= 'o', markersize = 10, color = 'blue', markerfacecolor='blue', linewidth = 2, label = '서구')
# ax.plot(df_table.loc[:,'연제구'],marker= 'o', markersize = 10, color = 'blue', markerfacecolor='blue', linewidth = 2, label = '연제구')
# ax.plot(df_table.loc[:,'영도구'],marker= 'o', markersize = 10, color = 'blue', markerfacecolor='blue', linewidth = 2, label = '영도구')
# ax.plot(df_table.loc[:,'중구'],marker= 'o', markersize = 10, color = 'blue', markerfacecolor='blue', linewidth = 2, label = '동구')
ax.plot(df_table.loc[:,'사하구'],marker= 'o', markersize = 10, color = 'black', markerfacecolor='black', linewidth = 2, label = '사하구')
# ax.plot.xlabel('지역(구)', size=25)
# ax.plot.ylabel('총 콜택시 통화건수',size=25)
ax.legend(loc='upper right')
plt.show()

# %%
df_table2 = df2.pivot_table('통화건수',columns='발신지_시군구',index='요일',aggfunc='mean',fill_value=0)
df_table2
# Out:
# 발신지_시군구       강서구       금정구        기장군         남구        동구       동래구  \
# 요일
# 금        5.045455  7.488670  14.744118  11.796083  5.264706  9.825993
# 목        5.026772  6.842540  12.770169   9.877100  5.172632  8.404592
# 수        5.021605  6.967188  12.973193  10.160036  5.213034  8.330016
# 월        5.007848  6.455310  11.961736   9.098669  5.164136  7.628941
# 일        5.001214  6.234010  10.245929   8.061437  5.114682  6.894790
# 토        5.035230  6.878131  13.464162  10.445400  5.309491  9.034332
# 화        5.011351  6.785150  12.419110   9.550909  5.156591  8.058688
#
# 발신지_시군구       부산진구         북구       사상구       사하구        서구       수영구  \
# 요일
# 금        11.878223  11.317536  6.639956  8.884031  5.881290  7.516402
# 목        10.806248  10.011510  6.092769  8.050104  5.640538  6.709265
# 수        10.914864  10.010291  6.234097  8.282528  5.698747  6.773250
# 월        10.467992   9.413634  5.888655  7.756565  5.480952  6.452212
# 일         9.075466   9.458993  5.662321  7.429025  5.524691  5.808639
# 토        10.940507  11.027265  6.434106  8.774688  5.929673  6.933732
# 화        10.519269   9.614100  6.010480  7.966214  5.583605  6.580386
#
# 발신지_시군구        연제구       영도구        중구       해운대구
# 요일
# 금        13.530923  5.937168  5.007117  13.539189
# 목        11.278095  5.618001  5.002632  11.664364
# 수        11.554054  5.740454  5.021519  11.529099
# 월        10.276657  5.479510  5.005472  10.528311
# 일         8.841141  5.303113  5.028736   8.964056
# 토        11.037736  5.754506  5.019900  12.467621
# 화        10.652299  5.541232  5.002653  10.848784

# %%
df_table.sum()
# Out:
# 발신지_시군구
# 강서구      68263
# 금정구      93981
# 기장군     265507
# 남구      154971
# 동구       51809
# 동래구     180595
# 부산진구    270459
# 북구      158139
# 사상구     148093
# 사하구     170303
# 서구       85873
# 수영구      89320
# 연제구      80234
# 영도구      76582
# 중구       26957
# 해운대구    336233
# dtype: int64

# %%
df_table = df22.pivot_table('통화건수',columns='요일',index='시간대',aggfunc='sum',fill_value=0)
df_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-b22de135a1d4> in <module>
# ----> 1 df_table = df22.pivot_table('통화건수',columns='요일',index='시간대',aggfunc='sum',fill_value=0)
#       2 df_table
#
# NameError: name 'df22' is not defined

# %%
df_group = df.groupby(['요일','시간대']).sum()

# %%
# %matplotlib inline
import pandas as pd
import cx_Oracle as oci
import matplotlib.pyplot as plt

conn = oci.connect('admin/1234@192.168.99.100:32764/xe',encoding='utf-8')
df = pd.read_sql_query('SELECT * FROM TAXI',conn)
df_week = pd.read_sql_query('SELECT * FROM FP_WEEK',conn)
df_time = pd.read_sql_query('SELECT * FROM FP_TIME',conn)
df_week.columns = ['No','연도','월','요일','시군구','읍면동','유동인구']
df_time.columns = ['No','연도','월','시간','시군구','유동인구']
# Out:
#           No    연도   월 요일  시군구   읍면동          유동인구
# 0        292  2016  02  일   동구  범일5동  10871.642578
# 1        293  2016  03  일   동구  초량1동  82740.718750
# 2        294  2016  03  일   동구  초량2동  34222.496094
# 3        295  2016  03  일   동구  초량3동  46415.982422
# 4        296  2016  03  일   동구  초량6동  16661.600586
# ...      ...   ...  .. ..  ...   ...           ...
# 61545  61179  2019  05  토  강서구   강동동   5224.555176
# 61546  61180  2019  05  토  강서구   가락동   3186.100098
# 61547  61181  2019  05  토  강서구   녹산동  34141.000000
# 61548  61182  2019  05  토  강서구  가덕도동   5127.924805
# 61549  61183  2019  06  토  강서구  대저1동   8965.240234
#
# [61550 rows x 7 columns]

# %%
df_time2 = df_time[(df_time['시간'] == 7) | (df_time['시간'] == 8) | (df_time['시간'] == 9)]
night_m_t = df_time2.groupby('시군구').mean()['유동인구']
plt.style.use('ggplot')
night_m_t[['강서구','금정구','기장군','남구','동구','동래구','부산진구','북구','사상구','사하구','서구','수영구','연제구','영도구','중구','해운대구']].plot(kind='bar',figsize=(20,10),width=0.7,color ='lightcoral')
# plt.ylim(0,15)
plt.xticks(rotation=45)
plt.xlabel('지역(구)', size=25)
plt.ylabel('유동인구', size=25)
plt.title('지역구에 따른 평균 유동인구 : 출근 시간대',size=30)
# plt.set_xticklabels(df_year_event.index, rotation = 75)
plt.show()
# night_m

# %%
df2 = df[(df['시간대'] == 7) | (df['시간대'] == 8) | (df['시간대'] == 9)]
night_m = df2.groupby('발신지_시군구').sum()['통화건수']
plt.style.use('ggplot')
night_m[['강서구','금정구','기장군','남구','동구','동래구','부산진구','북구','사상구','사하구','서구','수영구','연제구','영도구','중구','해운대구']].plot(kind='bar',figsize=(20,10),width=0.7,color ='mediumslateblue')
# plt.ylim(0,350000)
plt.xticks(rotation=45)
plt.xlabel('지역(구)', size=25)
plt.ylabel('콜택시',size=25)
plt.facecolor=None

plt.title('지역구에 따른 콜택시 통화건수 총합 : 출근 시간대',size=30)
plt.savefig('./save.png', dpi=300,facecolor=None)
plt.show()

# %%
df_total = pd.DataFrame()
df_total['유동인구'] = night_m_t
df_total['통화건수'] = night_m
df_total
# Out:
#               유동인구    통화건수
# 시군구
# 강서구   38125.244552   59262
# 금정구   13029.085869  140648
# 기장군   33322.885245  242475
# 남구    13226.836526  259813
# 동구     8189.684530   57698
# 동래구   18772.568679  304233
# 부산진구  17482.949379  428752
# 북구    17144.122013  262261
# 사상구   23589.145068  219318
# 사하구   19202.348113  280307
# 서구     8280.623832  112800
# 수영구   15439.202965  130870
# 연제구   15558.898575  134322
# 영도구    8602.465532  115799
# 중구    10068.775319   27439
# 해운대구  20761.475569  471925

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(1,1,1)
ax1 = night_m.plot(kind='bar',figsize=(20,10),width=0.7,color ='mediumslateblue')
ax2 = ax1.twinx()
ax2.plot(night_m_t,marker='*',markersize=10)
plt.xticks(rotation=45)
ax1.set_xlabel('지역(구)', size=25)
ax1.set_ylabel('총 콜택시 통화건수',size=25)
ax2.set_ylabel('유동인구',size=25)

plt.title('지역구에 따른 콜택시 통화건수 총합 : 퇴근 시간대',size=30)
# Out:
# Text(0.5, 1.0, '지역구에 따른 콜택시 통화건수 총합 : 퇴근 시간대')

# %%
week_m = df_week.groupby('요일').mean()['유동인구']

week_m = df_week.pivot_table('유동인구',columns='요일',index='시군구',aggfunc='mean',fill_value=0)



plt.style.use('ggplot')
week_m.plot(kind='bar',figsize=(20,10),width=0.7)
# plt.ylim(0,250000000)
# fig = plt.figure(figsize=(20,10))
# ax1 = fig.add_subplot(1,1,1)
# ax1 = [['월','화','수','목','금','토','일']].plot(kind='bar',figsize=(20,10),width=0.7,color ='mediumslateblue')
# plt.xticks(rotation=45)
# ax1.set_xlabel('요일', size=25)
# ax1.set_ylabel('총 콜택시 통화건수',size=25)


plt.title('요일에 유동인구 평균',size=30)
# Out:
# Text(0.5, 1.0, '요일에 유동인구 평균')

# %%
week_m
# Out:
# 요일               금             목             수             월             일  \
# 시군구
# 강서구   34603.981280  34461.813783  34582.780092  34174.133618  35938.885966
# 금정구   13768.439409  13811.767740  13932.068427  13929.038157  19137.724100
# 기장군   28582.611509  28549.915606  28793.082770  28714.418888  43555.008782
# 남구    13762.525767  13896.817413  13914.243060  13967.609288  18434.051649
# 동구     9692.982403   9542.048876   9448.538102   9498.969490  12830.693180
# 동래구   19665.368556  19567.892282  19594.683358  19601.657053  26942.320338
# 부산진구  22058.789953  21872.634232  21796.967544  21874.670031  28780.803292
# 북구    17615.916564  17534.155629  17719.526494  17798.727309  25096.211538
# 사상구   21742.860919  21792.570270  21973.275547  21925.216170  26475.573502
# 사하구   18501.505214  18608.158173  18854.597906  18788.665580  23747.773076
# 서구     8409.902500   8510.613953   8539.340235   8621.445518  12364.909740
# 수영구   17341.952211  17198.461946  17248.047752  17267.912734  24435.238287
# 연제구   16837.898841  16857.755467  16878.485622  16883.174668  22420.095431
# 영도구    8716.683751   8796.489862   8808.906646   8911.668767  12807.492891
# 중구    15604.556585  15258.996552  15119.907856  15110.546386  23304.914711
# 해운대구  21364.620171  21093.361669  21028.800707  21100.088343  30572.496775
#
# 요일               토             화
# 시군구
# 강서구   29257.526240  40405.996905
# 금정구   13909.815078  14488.897361
# 기장군   32390.922545  33918.575287
# 남구    13433.199911  14120.204092
# 동구     9048.610923   8662.234855
# 동래구   20193.589425  19701.914854
# 부산진구  22373.281590  22809.512357
# 북구    18337.520531  17944.897807
# 사상구   20633.846308  23308.719257
# 사하구   17725.626839  19643.278987
# 서구     8191.706775   7268.022653
# 수영구   18650.416100  17071.373889
# 연제구   16113.136353  15945.299996
# 영도구    8693.577778   7781.321647
# 중구    16235.934691  11960.786566
# 해운대구  23089.744156  21744.151582

# %%
# %matplotlib inline
import pandas as pd
import cx_Oracle as oci
import matplotlib.pyplot as plt

conn = oci.connect('admin/1234@192.168.99.100:32764/xe',encoding='utf-8')
df = pd.read_sql_query('SELECT * FROM TAXI',conn)
df_week = pd.read_sql_query('SELECT * FROM FP_WEEK',conn)
df_time = pd.read_sql_query('SELECT * FROM FP_TIME',conn)
df.columns = ['No','기준년월일','요일','시간대','발신지_시도','발신지_시군구','발신지_읍면동','통화건수']
df_week.columns = ['No','연도','월','요일','시군구','읍면동','유동인구']
df_time.columns = ['No','연도','월','시간','시군구','유동인구']


all_time_total = pd.DataFrame()
night_total = pd.DataFrame()
all_time_t = df_time.groupby('시군구').mean()['유동인구']
all_time_t
all_time = df.groupby('발신지_시군구').sum()['통화건수']
all_time

all_time_total['유동인구'] = all_time_t
all_time_total['통화건수'] = all_time
all_time_total

# all_time_total.corr()

df2 = df[(df['시간대'] == 18) | (df['시간대'] == 19) | (df['시간대'] == 20)]
night_m = df2.groupby('발신지_시군구').sum()['통화건수']
df_time2 = df_time[(df_time['시간'] == 18) | (df_time['시간'] == 19) | (df_time['시간'] == 20)]
night_m_t = df_time2.groupby('시군구').mean()['유동인구']

night_total['유동인구'] = night_m_t
night_total['통화건수'] = night_m
night_total

# night_total.corr()
# Out:
#           유동인구      통화건수
# 유동인구  1.000000  0.631292
# 통화건수  0.631292  1.000000

# %%
df2 = df[(df['시간대'] == 7) | (df['시간대'] == 8) | (df['시간대'] == 9)]
night_m = df2.groupby('발신지_시군구').sum()['통화건수']
plt.style.use('ggplot')
night_m[['강서구','금정구','기장군','남구','동구','동래구','부산진구','북구','사상구','사하구','서구','수영구','연제구','영도구','중구','해운대구']].plot(kind='bar',figsize=(20,10),width=0.7,color ='mediumslateblue')
# plt.ylim(0,350000)
plt.xticks(rotation=45)
plt.xlabel('지역(구)', size=25)
plt.ylabel('콜택시',size=25)
plt.facecolor=None

plt.title('지역구에 따른 콜택시 통화건수 총합 : 출근 시간대',size=30)
plt.savefig('./save.png', dpi=300,facecolor=None)
plt.show()
